# %% [markdown]
# # But where are my closest wineries?
# #### Problem:  Oregon wine pass is great, all these wineries offer great deals, but crawling around their website to find the wineries that are closest sucks.  Also, wouldn't it be great to know the ratings before you went there?
# 1. Scrape Wine Passport site
# 2. Call Google API for map distances
# 3. todo: Get reviews from YELP
# 4. todo: Topic model reviews on YELP
# 5. todo: Return df with Name, address, distance, ratings, review topics

# %%
from requests import get
from bs4 import BeautifulSoup
import pandas as pd
import json
from datetime import datetime, timedelta
import re

# %%
# i keep address and api key in separate config because privacy
with open("wine_config.json", "r") as f:
    wine_config = json.load(f)

# here's the OWP's handy dandy website
url = r'https://oregonwinepass.com/sponsor-type/wineries/'
api_base = 'https://maps.googleapis.com/maps/api/directions/json?'
my_addr = wine_config['address']
myk = wine_config['map_api']

# %% [markdown]
# ##### Totally overkill, but I copy and pasted, so it's okay!

# %%
raw_html = get(url)
soup = BeautifulSoup(raw_html.content, 'html.parser')

# %%
wineries = soup.find_all("h3", class_="entry-title scroll-top")
addresses = soup.find_all("span", class_="addr")
winery_list = [x.contents[1].string.strip() for x in wineries]
addr_list = [x.contents[0].string.strip() for x in addresses]

# %%
details = soup.find_all("div", class_="details")
details_list = [x.findChildren("li") for x in details]
wine_dict = {}

# %% [markdown]
# ##### WInery detials are a little funky since there are more than 1 for each winery

# %%
# that shib is burried in there, let's get her out jim
details_list[0][0].contents[0]
# Out:
# '2-for-1 Wine Tasting'

# %% [markdown]
# ##### I'm certain there is a more efficient way of doing this

# %%
for i in range(len(winery_list)):
    sub_details = details_list[i]
    sub_list = [x.contents[0] for x in sub_details]
    wine_dict[winery_list[i]] = sub_list
    
wine_details_df = pd.DataFrame.from_dict(wine_dict, orient='index')
wine_details_df.head()
# Out:
#                                                            0  \
# AlexEli Vineyard                        2-for-1 Wine Tasting
# Angel Vine                       Bonus pour with Tasting Fee
# Anindor Vineyards                Complimentary tasting for 2
# ArborBrook Vineyards                         2 for 1 tasting
# Archer Vineyard       2 for 1 tasting (regularly $20/person)
#
#                                                                       1  \
# AlexEli Vineyard                              10% off 4 Bottle Purchase
# Angel Vine                                 10% off all bottle purchases
# Anindor Vineyards                                10% off wine purchases
# ArborBrook Vineyards                          10% off on wine purchases
# Archer Vineyard       waived tasting fee with a purchase of any 4 wi...
#
#                                                         2     3
# AlexEli Vineyard                                     None  None
# Angel Vine            15% off case purchase – mix & match  None
# Anindor Vineyards                                    None  None
# ArborBrook Vineyards                                 None  None
# Archer Vineyard                20% off $100 wine purchase  None

# %% [markdown]
# ##### gut check we didn't mess anything up thus far

# %%
assert len(wine_details_df) == len(addr_list), 'you done did messed up'
# thank god these are in order, amirite?
wine_details_df['address'] = addr_list

# %%
wine_details_df.head()
# Out:
#                                                            0  \
# AlexEli Vineyard                        2-for-1 Wine Tasting
# Angel Vine                       Bonus pour with Tasting Fee
# Anindor Vineyards                Complimentary tasting for 2
# ArborBrook Vineyards                         2 for 1 tasting
# Archer Vineyard       2 for 1 tasting (regularly $20/person)
#
#                                                                       1  \
# AlexEli Vineyard                              10% off 4 Bottle Purchase
# Angel Vine                                 10% off all bottle purchases
# Anindor Vineyards                                10% off wine purchases
# ArborBrook Vineyards                          10% off on wine purchases
# Archer Vineyard       waived tasting fee with a purchase of any 4 wi...
#
#                                                         2     3  \
# AlexEli Vineyard                                     None  None
# Angel Vine            15% off case purchase – mix & match  None
# Anindor Vineyards                                    None  None
# ArborBrook Vineyards                                 None  None
# Archer Vineyard                20% off $100 wine purchase  None
#
#                                                         address
# AlexEli Vineyard              35803 South Highway 213 , Molalla
# Angel Vine                         2025 SE 7th Avenue, Portland
# Anindor Vineyards                       1171 Vintage Dr, Elkton
# ArborBrook Vineyards            17770 NE Calkins Lane , Newberg
# Archer Vineyard       32230 NE Old Parrett Mountain Rd, Newberg

# %%
def replace_reserved(string):
    '''remove reserved url/uri characters'''
    for char in [';' , '/' , '?' , ':' , '@' , '&' , '=' , '+' , '$' , ',' , '#']:
        if char in string:
            string = string.replace(char, '')
    
    return string
    
def time_string(string):
    '''deal with google apis deal of formatting times nicely for humans'''
    if 'hours' in string and 'mins' in string:
        t = datetime.strptime(string, '%H hours %M mins')
    
    elif 'hour' not in string and 'mins' in string:
        t = datetime.strptime(string, '%M mins') 
    elif 'mins' in string:
        t = datetime.strptime(string, '%H hour %M mins')
    
    elif 'hours' in string:
        t = datetime.strptime(string, '%H hours %M min')
    else:
        t = datetime.strptime(string, '%H hour %M min')
    
    time_str = str(timedelta(hours=t.hour, minutes=t.minute, seconds=t.second))
    
    return time_str
    
    
def route_data(address):
    '''return distance and formatted duration a given address'''
    address = replace_reserved(address)
    dest = (address.replace(' ', '+'))
    api_str = api_base + 'origin=' + dest + '&destination=' + my_addr + '+Oregon' + '&key=' + myk
    # call api
    resp = get(api_str)
    json_resp = resp.json()
    dist = json_resp['routes'][0]['legs'][0]['distance']['text']
    duration = json_resp['routes'][0]['legs'][0]['duration']['text']
    dura = time_string(duration)
    
    return (dist, dura)

# %% [markdown]
# ##### Loop through all address and return distance and duration in lists

# %%
dists = []
durations = []

for address in wine_details_df['address']:
    dist, duration = route_data(address)
    dists.append(dist)
    durations.append(duration)

# %% [markdown]
# ##### Add distrance and duration to dataframe, sort

# %%
wine_details_df['duration'] = durations
wine_details_df['distances'] = dists
wine_details_df.sort_values(by='duration', inplace=True)

wine_details_df
# Out:
#                                                                                            0  \
# Namaste Vineyards                                                            2-for-1 Tasting
# Willamette Valley Vineyards                                      Complimentary tasting for 2
# Johan Vineyards                                                  Complimentary tasting for 2
# Coria Estates                                                    Complimentary Tasting for 2
# Van Duzer Vineyards                                                          2 for 1 tasting
# Pfeiffer Winery                            enjoy 2 complimentary pinot plus tastings in t...
# Silas Wines                                                                  2 for 1 tasting
# Franny Beck Wines                          Complimentary tasting for two with a one bottl...
# Coelho Winery                                                                2 for 1 tasting
# Mystic Wine                                                                  2-for-1 Tasting
# Grochau Cellars                                                              2-for-1 Tasting
# Naked Winery- McMinnville                                        Complimentary tasting for 2
# J. Scott Cellars                                                             2 for 1 tasting
# Elizabeth Chambers Cellar                                                    2 for 1 tasting
# Terra Vina                                                                   2 for 1 Tasting
# Yamhill Valley Vineyards                                                    2 for 1 tastings
# Walnut City WineWorks                                Enjoy a complimentary flight of 5 wines
# Vitis Ridge                                                               10% off any bottle
# Aurora Cellars at Aurora Colony Vineyards                                               None
# Silvan Ridge Winery                              Complimentary tastings for passport members
# Saginaw Vineyard                           Complimentary tasting for passport members and...
# Hyland Estates                                                              2 for 1 Tastings
# Troon Vineyard – Carlton                                         Complimentary tasting for 2
# Stone Griffon Vineyard                                                       2 for 1 tasting
# Gypsy Dancer Wines                                                           2-for-1 tasting
# Hanson Vineyards                                                            2 for 1 tastings
# Carlton Cellars                                                 Complimentary tastings for 2
# Longplay Wine                                                    Complimentary tasting for 2
# Cliff Creek Cellars-Newberg                                                 2 for 1 Tastings
# Vintyr Wine                                                             2-for-1 wine tasting
# ...                                                                                      ...
# Angel Vine                                                       Bonus pour with Tasting Fee
# Forest Edge Vineyard                              Complimentary tasting for Passport Members
# SakéOne                                    Two complimentary Toji Flights (flight of 6 in...
# Blooming Hill Vineyard                                                      2 for 1 tastings
# David Hill Vineyard & Winery                                                2 for 1 Tastings
# D’ Anu Wines                                                     Bonus pour with Tasting Fee
# Risdall Ranch Winery                                                   2 for 1 wine tastings
# Bradley Vineyards                                                Complimentary tasting for 2
# River’s Edge Winery                                              Complimentary tasting for 2
# Anindor Vineyards                                                Complimentary tasting for 2
# Buddha Kat Winery                          complimentary tasting for two 2 ( 4/1 oz. tast...
# HV Cellars                                                             Complimentary Tasting
# Delfino Vineyards                                                Complimentary tasting for 2
# Freed Estate Winery                                              Complimentary tasting for 2
# Naked Winery- Hood River                                         Complimentary tasting for 2
# Cascade Cliffs Vineyard & Winery                                                        None
# Stoltz Winery                                                    complimentary tasting for 2
# Naked Winery- Seaside                                            Complimentary tasting for 2
# Naked Winery- Bend                                               Complimentary tasting for 2
# Ledger David                                                     complimentary tasting for 2
# Rosella’s Vineyard & Winery                                            Complimentary tasting
# Schmidt Family Vineyards                                                     2 for 1 Tasting
# Troon Vineyard – Applegate Valley                                Complimentary tasting for 2
# Cliff Creek Cellars                                                         2 for 1 Tastings
# Deer Creek Vineyards                                             Complimentary tasting for 2
# Devitt Winery                                                    Complimentary tasting for 2
# RoxyAnn Winery                                                   complimentary tasting for 2
# LongSword Vineyard                                                           2 for 1 Tasting
# Echo Ridge Cellars                                               Complimentary Tasting for 2
# Triple Oak Wine Vault                                           Complimentary tastings for 2
#
#                                                                                            1  \
# Namaste Vineyards                                  10% off any purchase of 3 bottles or more
# Willamette Valley Vineyards                                            10% off wine purchase
# Johan Vineyards                                                                         None
# Coria Estates                                                       10% off bottle purchases
# Van Duzer Vineyards                                             10% off of 3 bottles or more
# Pfeiffer Winery                                                                         None
# Silas Wines                                          10% off a purchase of 6 or more bottles
# Franny Beck Wines                                         10% off with a six bottle purchase
# Coelho Winery                                     10% off wine purchase on 6 or more bottles
# Mystic Wine                                                          5% off of wine purchase
# Grochau Cellars                                      10% off a purchase of 6 or more bottles
# Naked Winery- McMinnville                                                               None
# J. Scott Cellars                                                                        None
# Elizabeth Chambers Cellar                                                               None
# Terra Vina                                                         10% off 2 or more bottles
# Yamhill Valley Vineyards                                                   10% off purchases
# Walnut City WineWorks                                                                   None
# Vitis Ridge                                       15% off six or 20% off cases, mix or match
# Aurora Cellars at Aurora Colony Vineyards                                               None
# Silvan Ridge Winery                                                                     None
# Saginaw Vineyard                                                10% off all bottle purchases
# Hyland Estates                                                    14% off all wine purchases
# Troon Vineyard – Carlton                                 15% discount on a 6 bottle purchase
# Stone Griffon Vineyard                                                     15% off purchases
# Gypsy Dancer Wines                         10% discounts on bottle purchases, 20% off cas...
# Hanson Vineyards                                           10% discount on 6 bottle purchase
# Carlton Cellars                                           10% discount on all wine purchases
# Longplay Wine                                                                           None
# Cliff Creek Cellars-Newberg                        10% off any purchase of 3 bottles or more
# Vintyr Wine                                10% off wine purchases (when purchasing three ...
# ...                                                                                      ...
# Angel Vine                                                      10% off all bottle purchases
# Forest Edge Vineyard                                         10% discount off wine purchases
# SakéOne                                                                                 None
# Blooming Hill Vineyard                                  10% discount on any bottle purchases
# David Hill Vineyard & Winery                                       10% off any wine purchase
# D’ Anu Wines                                                    10% off all bottle purchases
# Risdall Ranch Winery                                                15% off bottle purchases
# Bradley Vineyards                                                                       None
# River’s Edge Winery                                                                     None
# Anindor Vineyards                                                     10% off wine purchases
# Buddha Kat Winery                          Buy a case of 12 and only pay for 11 (does not...
# HV Cellars                                                             10% off all purchases
# Delfino Vineyards                                                 10% off all wine purchases
# Freed Estate Winery                                                    10% off wine purchase
# Naked Winery- Hood River                                                                None
# Cascade Cliffs Vineyard & Winery                                                        None
# Stoltz Winery                                                       20% off bottle purchases
# Naked Winery- Seaside                                                                   None
# Naked Winery- Bend                                                                      None
# Ledger David                                  10% discount on purchases of 3 bottles or more
# Rosella’s Vineyard & Winery                                                             None
# Schmidt Family Vineyards                                              10% off Wine Purchases
# Troon Vineyard – Applegate Valley                        15% discount on a 6 bottle purchase
# Cliff Creek Cellars                                10% off any purchase of 3 bottles or more
# Deer Creek Vineyards                                               10% off 3 bottles or more
# Devitt Winery                              10% discount on the purchase of 3 or more bottles
# RoxyAnn Winery                                10% discount on purchases of 3 bottles or more
# LongSword Vineyard                                                    10% off Wine Purchases
# Echo Ridge Cellars                                     10% Off Purchase of 3 Bottles or More
# Triple Oak Wine Vault                                      Participants receive a small gift
#
#                                                                                            2  \
# Namaste Vineyards                                                                       None
# Willamette Valley Vineyards                Passport Member benefits does NOT apply on win...
# Johan Vineyards                                                                         None
# Coria Estates                                                                           None
# Van Duzer Vineyards                                                                     None
# Pfeiffer Winery                                                                         None
# Silas Wines                                                                             None
# Franny Beck Wines                                                                       None
# Coelho Winery                                                                           None
# Mystic Wine                                                                             None
# Grochau Cellars                                                                         None
# Naked Winery- McMinnville                                                               None
# J. Scott Cellars                                                                        None
# Elizabeth Chambers Cellar                                                               None
# Terra Vina                                               15% off case purchase – mix & match
# Yamhill Valley Vineyards                                                                None
# Walnut City WineWorks                                                                   None
# Vitis Ridge                                                                             None
# Aurora Cellars at Aurora Colony Vineyards                                               None
# Silvan Ridge Winery                                                                     None
# Saginaw Vineyard                                                                        None
# Hyland Estates                                                           10% off merchandise
# Troon Vineyard – Carlton                                                                None
# Stone Griffon Vineyard                                                                  None
# Gypsy Dancer Wines                                                                      None
# Hanson Vineyards                                               20% discount on case purchase
# Carlton Cellars                                                                         None
# Longplay Wine                                                                           None
# Cliff Creek Cellars-Newberg                                                             None
# Vintyr Wine                                                                             None
# ...                                                                                      ...
# Angel Vine                                               15% off case purchase – mix & match
# Forest Edge Vineyard                                                                    None
# SakéOne                                                                                 None
# Blooming Hill Vineyard                     Not eligible for non-Membership tasting room o...
# David Hill Vineyard & Winery                                                            None
# D’ Anu Wines                                             15% off case purchase – mix & match
# Risdall Ranch Winery                                                                    None
# Bradley Vineyards                                                                       None
# River’s Edge Winery                                                                     None
# Anindor Vineyards                                                                       None
# Buddha Kat Winery                                        10% off purchase of 6 to 10 bottles
# HV Cellars                                                                              None
# Delfino Vineyards                                                                       None
# Freed Estate Winery                                                                     None
# Naked Winery- Hood River                                                                None
# Cascade Cliffs Vineyard & Winery                                                        None
# Stoltz Winery                                                                           None
# Naked Winery- Seaside                                                                   None
# Naked Winery- Bend                                                                      None
# Ledger David                                                                            None
# Rosella’s Vineyard & Winery                                                             None
# Schmidt Family Vineyards                                                                None
# Troon Vineyard – Applegate Valley                                                       None
# Cliff Creek Cellars                                                                     None
# Deer Creek Vineyards                                         20% discount on a case purchase
# Devitt Winery                                                 20% discount on case purchases
# RoxyAnn Winery                                                                          None
# LongSword Vineyard                                                                      None
# Echo Ridge Cellars                                                                      None
# Triple Oak Wine Vault                                                                   None
#
#                                               3  \
# Namaste Vineyards                          None
# Willamette Valley Vineyards                None
# Johan Vineyards                            None
# Coria Estates                              None
# Van Duzer Vineyards                        None
# Pfeiffer Winery                            None
# Silas Wines                                None
# Franny Beck Wines                          None
# Coelho Winery                              None
# Mystic Wine                                None
# Grochau Cellars                            None
# Naked Winery- McMinnville                  None
# J. Scott Cellars                           None
# Elizabeth Chambers Cellar                  None
# Terra Vina                                 None
# Yamhill Valley Vineyards                   None
# Walnut City WineWorks                      None
# Vitis Ridge                                None
# Aurora Cellars at Aurora Colony Vineyards  None
# Silvan Ridge Winery                        None
# Saginaw Vineyard                           None
# Hyland Estates                             None
# Troon Vineyard – Carlton                   None
# Stone Griffon Vineyard                     None
# Gypsy Dancer Wines                         None
# Hanson Vineyards                           None
# Carlton Cellars                            None
# Longplay Wine                              None
# Cliff Creek Cellars-Newberg                None
# Vintyr Wine                                None
# ...                                         ...
# Angel Vine                                 None
# Forest Edge Vineyard                       None
# SakéOne                                    None
# Blooming Hill Vineyard                     None
# David Hill Vineyard & Winery               None
# D’ Anu Wines                               None
# Risdall Ranch Winery                       None
# Bradley Vineyards                          None
# River’s Edge Winery                        None
# Anindor Vineyards                          None
# Buddha Kat Winery                          None
# HV Cellars                                 None
# Delfino Vineyards                          None
# Freed Estate Winery                        None
# Naked Winery- Hood River                   None
# Cascade Cliffs Vineyard & Winery           None
# Stoltz Winery                              None
# Naked Winery- Seaside                      None
# Naked Winery- Bend                         None
# Ledger David                               None
# Rosella’s Vineyard & Winery                None
# Schmidt Family Vineyards                   None
# Troon Vineyard – Applegate Valley          None
# Cliff Creek Cellars                        None
# Deer Creek Vineyards                       None
# Devitt Winery                              None
# RoxyAnn Winery                             None
# LongSword Vineyard                         None
# Echo Ridge Cellars                         None
# Triple Oak Wine Vault                      None
#
#                                                                                    address  \
# Namaste Vineyards                                           3250 Pacific Hwy, Independence
# Willamette Valley Vineyards                                  8800 Enchanted Way SE, Turner
# Johan Vineyards                                            4285 N Pacific Hwy W, Rickreall
# Coria Estates                                                  8252 Redstone Ave SE, Salem
# Van Duzer Vineyards                                            11975 Smithfield Rd, Dallas
# Pfeiffer Winery                                             25040 Jaeg Road, Junction City
# Silas Wines                                                            100 5th St. , Amity
# Franny Beck Wines                                                        108 5th St, Amity
# Coelho Winery                                                           111 5th St., Amity
# Mystic Wine                                               11931 SE Hood View Road  , Amity
# Grochau Cellars                                             9360 SE Eola Hills Road, Amity
# Naked Winery- McMinnville                                   211 NE 3rd Street, McMinnville
# J. Scott Cellars                                              520 Commercial St #G, Eugene
# Elizabeth Chambers Cellar                                   455 NE Irvine St., McMinnville
# Terra Vina                                                585 NE Third Street, McMinnville
# Yamhill Valley Vineyards                               16250 SW Oldsville Rd., McMinnville
# Walnut City WineWorks                                     475 NE 17th Street , McMinnville
# Vitis Ridge                                                 6685 Meridian Rd NE, Silverton
# Aurora Cellars at Aurora Colony Vineyards                        21338 Oak Lane NE, Aurora
# Silvan Ridge Winery                                           27012 Briggs Hill Rd, Eugene
# Saginaw Vineyard                           80247 Delight Valley School Road, Cottage Grove
# Hyland Estates                                            20980 NE Niederberger Rd, Dundee
# Troon Vineyard – Carlton                                  250 North Kutch Street , Carlton
# Stone Griffon Vineyard                                             223 W Main St , Carlton
# Gypsy Dancer Wines                                                143 Main Street, Carlton
# Hanson Vineyards                                              34948 S. Barlow Rd, Woodburn
# Carlton Cellars                                            130 West Monroe Street, Carlton
# Longplay Wine                                                  215 E First Street, Newberg
# Cliff Creek Cellars-Newberg                                         214 E 1st St., Newberg
# Vintyr Wine                                                      300 E 1st Street, Newberg
# ...                                                                                    ...
# Angel Vine                                                    2025 SE 7th Avenue, Portland
# Forest Edge Vineyard                                     15640 S Spangler Rd., Oregon City
# SakéOne                                                       820 Elm Street, Forest Grove
# Blooming Hill Vineyard                                      5195 SW Hergert Rd., Cornelius
# David Hill Vineyard & Winery                        46350 NW David Hill Road, Forest Grove
# D’ Anu Wines                                                     173 NE 3rd Ave, Hillsboro
# Risdall Ranch Winery                               6200 N.W Gales Creek Road, Forest Grove
# Bradley Vineyards                                                  1000 Azalea Dr , Elkton
# River’s Edge Winery                                                 1395 River Dr , Elkton
# Anindor Vineyards                                                  1171 Vintage Dr, Elkton
# Buddha Kat Winery                                                    17020 Ruben Ln, Sandy
# HV Cellars                                                     304 NW Main Street, Winston
# Delfino Vineyards                                           3829 Colonial Road  , Roseburg
# Freed Estate Winery                                               430 Hooten Road, Winston
# Naked Winery- Hood River                                        102 2nd Street, Hood River
# Cascade Cliffs Vineyard & Winery                                211 Oak Street, Hood River
# Stoltz Winery                                                 514 State Street, Hood River
# Naked Winery- Seaside                                       270 S Columbia Street, Seaside
# Naked Winery- Bend                                        330 SW Powerhouse Rd, #110, Bend
# Ledger David                                            245 N. Front Street, Central Point
# Rosella’s Vineyard & Winery                              184 Missouri Flat Rd, Grants Pass
# Schmidt Family Vineyards                                      330 Kubli Rd   , Grants Pass
# Troon Vineyard – Applegate Valley                            1475 Kubli Rd.  , Grants Pass
# Cliff Creek Cellars                                          1015 McDonough Rd., Gold Hill
# Deer Creek Vineyards                                            2680 Deer Creek Rd., Selma
# Devitt Winery                                                  11412 Hwy 238, Jacksonville
# RoxyAnn Winery                                                3285 Hillcrest Road, Medford
# LongSword Vineyard                                          8555 Highway 238, Jacksonville
# Echo Ridge Cellars                                             551 North Thielsen St, Echo
# Triple Oak Wine Vault                                              137 Locust St , Oakland
#
#                                           duration distances
# Namaste Vineyards                          0:28:00   21.3 mi
# Willamette Valley Vineyards                0:35:00   25.5 mi
# Johan Vineyards                            0:40:00   30.1 mi
# Coria Estates                              0:40:00   27.7 mi
# Van Duzer Vineyards                        0:41:00   31.1 mi
# Pfeiffer Winery                            0:42:00   28.6 mi
# Silas Wines                                0:46:00   37.5 mi
# Franny Beck Wines                          0:46:00   37.5 mi
# Coelho Winery                              0:46:00   37.5 mi
# Mystic Wine                                0:54:00   43.2 mi
# Grochau Cellars                            0:55:00   39.7 mi
# Naked Winery- McMinnville                  0:57:00   44.5 mi
# J. Scott Cellars                           0:57:00   42.2 mi
# Elizabeth Chambers Cellar                  0:58:00   45.7 mi
# Terra Vina                                 0:59:00   44.7 mi
# Yamhill Valley Vineyards                   0:59:00   47.0 mi
# Walnut City WineWorks                      1:00:00   45.4 mi
# Vitis Ridge                                1:05:00   50.2 mi
# Aurora Cellars at Aurora Colony Vineyards  1:05:00   58.6 mi
# Silvan Ridge Winery                        1:06:00   49.3 mi
# Saginaw Vineyard                           1:06:00   64.3 mi
# Hyland Estates                             1:07:00   53.2 mi
# Troon Vineyard – Carlton                   1:09:00   51.7 mi
# Stone Griffon Vineyard                     1:09:00   51.7 mi
# Gypsy Dancer Wines                         1:09:00   51.7 mi
# Hanson Vineyards                           1:09:00   55.7 mi
# Carlton Cellars                            1:10:00   51.8 mi
# Longplay Wine                              1:11:00   55.7 mi
# Cliff Creek Cellars-Newberg                1:11:00   55.7 mi
# Vintyr Wine                                1:11:00   55.7 mi
# ...                                            ...       ...
# Angel Vine                                 1:27:00   79.2 mi
# Forest Edge Vineyard                       1:29:00   73.2 mi
# SakéOne                                    1:31:00   69.0 mi
# Blooming Hill Vineyard                     1:33:00   71.1 mi
# David Hill Vineyard & Winery               1:37:00   72.2 mi
# D’ Anu Wines                               1:40:00   73.9 mi
# Risdall Ranch Winery                       1:42:00   75.1 mi
# Bradley Vineyards                          1:43:00   99.2 mi
# River’s Edge Winery                        1:43:00   98.9 mi
# Anindor Vineyards                          1:46:00    102 mi
# Buddha Kat Winery                          1:48:00   94.5 mi
# HV Cellars                                 2:03:00    124 mi
# Delfino Vineyards                          2:05:00    123 mi
# Freed Estate Winery                        2:06:00    125 mi
# Naked Winery- Hood River                   2:23:00    141 mi
# Cascade Cliffs Vineyard & Winery           2:23:00    141 mi
# Stoltz Winery                              2:24:00    141 mi
# Naked Winery- Seaside                      2:42:00    150 mi
# Naked Winery- Bend                         2:43:00    130 mi
# Ledger David                               3:23:00    207 mi
# Rosella’s Vineyard & Winery                3:24:00    197 mi
# Schmidt Family Vineyards                   3:25:00    197 mi
# Troon Vineyard – Applegate Valley          3:26:00    198 mi
# Cliff Creek Cellars                        3:27:00    208 mi
# Deer Creek Vineyards                       3:33:00    207 mi
# Devitt Winery                              3:33:00    207 mi
# RoxyAnn Winery                             3:34:00    216 mi
# LongSword Vineyard                         3:39:00    210 mi
# Echo Ridge Cellars                         4:17:00    267 mi
# Triple Oak Wine Vault                      9:09:00    575 mi
#
# [75 rows x 7 columns]

# %%
wine_details_df.to_csv('oregon_wineries.csv')
